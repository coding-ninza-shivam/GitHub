# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/CourseMaterial/DataWrangling/main/flowerdataset.csv", header=None)

# %%
df.head(1)
# Out:
#               0            1             2            3        4
# 0  sepal_length  sepal_width  petal_length  petal_width  species

# %%
df.to_json(orient='records')
# Out:
# '[{"0":"sepal_length","1":"sepal_width","2":"petal_length","3":"petal_width","4":"species"},{"0":"5.1","1":"3.5","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"4.9","1":"3","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"4.7","1":"3.2","2":"1.3","3":"0.2","4":"Iris-setosa"},{"0":"4.6","1":"3.1","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3.6","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"5.4","1":"3.9","2":"1.7","3":"0.4","4":"Iris-setosa"},{"0":"4.6","1":"3.4","2":"1.4","3":"0.3","4":"Iris-setosa"},{"0":"5","1":"3.4","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"4.4","1":"2.9","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"4.9","1":"3.1","2":"1.5","3":"0.1","4":"Iris-setosa"},{"0":"5.4","1":"3.7","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"4.8","1":"3.4","2":"1.6","3":"0.2","4":"Iris-setosa"},{"0":"4.8","1":"3","2":"1.4","3":"0.1","4":"Iris-setosa"},{"0":"4.3","1":"3","2":"1.1","3":"0.1","4":"Iris-setosa"},{"0":"5.8","1":"4","2":"1.2","3":"0.2","4":"Iris-setosa"},{"0":"5.7","1":"4.4","2":"1.5","3":"0.4","4":"Iris-setosa"},{"0":"5.4","1":"3.9","2":"1.3","3":"0.4","4":"Iris-setosa"},{"0":"5.1","1":"3.5","2":"1.4","3":"0.3","4":"Iris-setosa"},{"0":"5.7","1":"3.8","2":"1.7","3":"0.3","4":"Iris-setosa"},{"0":"5.1","1":"3.8","2":"1.5","3":"0.3","4":"Iris-setosa"},{"0":"5.4","1":"3.4","2":"1.7","3":"0.2","4":"Iris-setosa"},{"0":"5.1","1":"3.7","2":"1.5","3":"0.4","4":"Iris-setosa"},{"0":"4.6","1":"3.6","2":"1","3":"0.2","4":"Iris-setosa"},{"0":"5.1","1":"3.3","2":"1.7","3":"0.5","4":"Iris-setosa"},{"0":"4.8","1":"3.4","2":"1.9","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3","2":"1.6","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3.4","2":"1.6","3":"0.4","4":"Iris-setosa"},{"0":"5.2","1":"3.5","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"5.2","1":"3.4","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"4.7","1":"3.2","2":"1.6","3":"0.2","4":"Iris-setosa"},{"0":"4.8","1":"3.1","2":"1.6","3":"0.2","4":"Iris-setosa"},{"0":"5.4","1":"3.4","2":"1.5","3":"0.4","4":"Iris-setosa"},{"0":"5.2","1":"4.1","2":"1.5","3":"0.1","4":"Iris-setosa"},{"0":"5.5","1":"4.2","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"4.9","1":"3.1","2":"1.5","3":"0.1","4":"Iris-setosa"},{"0":"5","1":"3.2","2":"1.2","3":"0.2","4":"Iris-setosa"},{"0":"5.5","1":"3.5","2":"1.3","3":"0.2","4":"Iris-setosa"},{"0":"4.9","1":"3.1","2":"1.5","3":"0.1","4":"Iris-setosa"},{"0":"4.4","1":"3","2":"1.3","3":"0.2","4":"Iris-setosa"},{"0":"5.1","1":"3.4","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3.5","2":"1.3","3":"0.3","4":"Iris-setosa"},{"0":"4.5","1":"2.3","2":"1.3","3":"0.3","4":"Iris-setosa"},{"0":"4.4","1":"3.2","2":"1.3","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3.5","2":"1.6","3":"0.6","4":"Iris-setosa"},{"0":"5.1","1":"3.8","2":"1.9","3":"0.4","4":"Iris-setosa"},{"0":"4.8","1":"3","2":"1.4","3":"0.3","4":"Iris-setosa"},{"0":"5.1","1":"3.8","2":"1.6","3":"0.2","4":"Iris-setosa"},{"0":"4.6","1":"3.2","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"5.3","1":"3.7","2":"1.5","3":"0.2","4":"Iris-setosa"},{"0":"5","1":"3.3","2":"1.4","3":"0.2","4":"Iris-setosa"},{"0":"7","1":"3.2","2":"4.7","3":"1.4","4":"Iris-versicolor"},{"0":"6.4","1":"3.2","2":"4.5","3":"1.5","4":"Iris-versicolor"},{"0":"6.9","1":"3.1","2":"4.9","3":"1.5","4":"Iris-versicolor"},{"0":"5.5","1":"2.3","2":"4","3":"1.3","4":"Iris-versicolor"},{"0":"6.5","1":"2.8","2":"4.6","3":"1.5","4":"Iris-versicolor"},{"0":"5.7","1":"2.8","2":"4.5","3":"1.3","4":"Iris-versicolor"},{"0":"6.3","1":"3.3","2":"4.7","3":"1.6","4":"Iris-versicolor"},{"0":"4.9","1":"2.4","2":"3.3","3":"1","4":"Iris-versicolor"},{"0":"6.6","1":"2.9","2":"4.6","3":"1.3","4":"Iris-versicolor"},{"0":"5.2","1":"2.7","2":"3.9","3":"1.4","4":"Iris-versicolor"},{"0":"5","1":"2","2":"3.5","3":"1","4":"Iris-versicolor"},{"0":"5.9","1":"3","2":"4.2","3":"1.5","4":"Iris-versicolor"},{"0":"6","1":"2.2","2":"4","3":"1","4":"Iris-versicolor"},{"0":"6.1","1":"2.9","2":"4.7","3":"1.4","4":"Iris-versicolor"},{"0":"5.6","1":"2.9","2":"3.6","3":"1.3","4":"Iris-versicolor"}, ...

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\data analysis\python\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\data analysis\python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\data analysis\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y)

# %%
import pandas as pd
sales_data_df=pd.read_csv('sales_data_sample.csv',encoding='ISO-8859-1')
hd=sales_data_df.head(5)

# %%
sales_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
total_sales_by_product=hd.groupby('CITY')['SALES'].sum()
print(total_sales_by_product)
# Out:
# CITY
# NYC              2871.00
# Paris            3884.34
# Pasadena         3746.70
# Reims            2765.90
# San Francisco    5205.27
# Name: SALES, dtype: float64

# %%
total_sales_by_product.plot(kind='bar', color='teal')
# Out:
# <Axes: xlabel='CITY'>

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\data analysis\python\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in e:\data analysis\python\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\data analysis\python\venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\data analysis\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\data analysis\python\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\data analysis\python\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in e:\data analysis\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
tips= sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill', y='tip',color='green', data=tips)
plt.title("Scatterplot of total bill vs tip")
plt.show()

# %%
sns.pairplot(tips)
